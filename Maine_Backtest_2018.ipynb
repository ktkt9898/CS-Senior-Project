# %% [markdown]
# # Maine Backtest Analysis, 2018 Polling Data vs 2018 Election Results
#
# <div>
# <img src="_static/images/maine_polling_backtest_2018.png" style="width: 100%;">
# </div>
#
# <br>
#
# <div>
# <img src="_static/images/maine_results_backtest_2018.png" style="width: 100%;">
# </div>
