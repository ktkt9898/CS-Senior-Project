# %% [markdown]
# # Georgia Election Prediction, Week 3
# ## September 14th - September 18th
#
# <div style="display: flex; justify-content: space-between;">
#     <img src="_static/images/georgia_graph_week_3.png" style="width: 100%;">
# </div>
