# %% [markdown]
# # Maine Election Prediction, Week 6
# ## October 5th - October 9th
#
# <div style="display: flex; justify-content: space-between;">
#     <img src="_static/images/maine_graph_week_6.png" style="width: 100%;">
# </div>
