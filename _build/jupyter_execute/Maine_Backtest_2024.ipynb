# %% [markdown]
# # Maine Backtest Analysis, 2024 Polling Data vs 2024 Election Results
#
# <div>
# <img src="_static/images/maine_polling_backtest_2024.png" style="width: 100%;">
# </div>
#
# <br>
#
# <div>
# <img src="_static/images/maine_results_backtest_2024.png" style="width: 100%;">
# </div>
