# %% [markdown]
# # Michigan Backtest Analysis, 2020 Polling Data vs 2020 Election Results
#
# <div>
# <img src="_static/images/michigan_polling_backtest_2020.png" style="width: 100%;">
# </div>
#
# <br>
#
# <div>
# <img src="_static/images/michigan_results_backtest_2020.png" style="width: 100%;">
# </div>
