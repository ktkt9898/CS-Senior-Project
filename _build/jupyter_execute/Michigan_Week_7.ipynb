# %% [markdown]
# # Michigan Election Prediction, Week 7
# ## October 12th - October 16
#
# <div style="display: flex; justify-content: space-between;">
#     <img src="_static/images/michigan_graph_week_7.png" style="width: 100%;">
# </div>
