# %% [markdown]
# # Maine Election Prediction, Week 8
# ## October 19th - October 23rd
#
# <div style="display: flex; justify-content: space-between;">
#     <img src="_static/images/maine_graph_week_8.png" style="width: 100%;">
# </div>
