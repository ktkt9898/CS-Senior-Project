# %% [markdown]
# # Georgia Backtest Analysis, 2022 Polling vs 2022 Results
#
# <img src="_static/images/georgia_polling_backtest_2022.png" style="width: 100%;">
#
# <br>
#
# <img src="_static/images/georgia_results_backtest_2022.png" style="width: 100%;">
