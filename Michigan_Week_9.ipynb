# %% [markdown]
# # Michigan Election Prediction, Week 9
# ## October 26th - October 30th
#
# <div style="display: flex; justify-content: space-between;">
#     <img src="_static/images/michigan_graph_week_9.png" style="width: 100%;">
# </div>
